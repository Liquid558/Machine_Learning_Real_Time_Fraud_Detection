# %%
from fraud_detector import FraudDetectionSystem

fd = FraudDetectionSystem()

if fd.load_model():
    fd.explain_system()
    fd.batch_test_transactions(10)
    fd.show_model_comparison()
# Out:
# Model loaded successfully.
#
# HOW THE FRAUD DETECTION SYSTEM WORKS
# ...
# • Analyzes credit card transactions for fraud.
# • Uses machine learning to find patterns.
# • Evaluates 30 features per transaction.
# • Outputs: FRAUD or LEGITIMATE with confidence level.
#
# FEATURES CONSIDERED:
# - Transaction Amount and Time
# - 28 PCA-anonymized security signals
# - User behavioral patterns
#
# Batch Test Results:
#  id      amount prediction  fraud_confidence
#   1 9999.000000 LEGITIMATE              26.0
#   2   15.000000 LEGITIMATE               0.0
#   3  168.232349 LEGITIMATE               0.0
#   4  116.212115 LEGITIMATE               0.0
#   5  180.079573 LEGITIMATE               0.0
#   6  370.602843 LEGITIMATE               1.0
#   7  655.853856 LEGITIMATE               0.0
#   8  301.839327 LEGITIMATE               1.0
#   9  253.238930 LEGITIMATE               0.0
#  10  346.031307 LEGITIMATE               1.0
#
# MODEL COMPARISON
# ...
